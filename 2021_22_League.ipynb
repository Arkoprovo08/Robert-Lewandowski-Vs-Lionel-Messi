# %%
# Import required libraries:
import json
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen
from sklearn.preprocessing import MinMaxScaler

# Import plotting libraries:
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from matplotlib.patches import Arc
from plotly.subplots import make_subplots

# %%
# Scrape RL player stats:
cris_scrape_url = "https://understat.com/player/227"
page_connect = urlopen(cris_scrape_url)
page_html = BeautifulSoup(page_connect, "html.parser")

json_raw_string = page_html.findAll(name="script")[1].text
start_ind = json_raw_string.index("\\")
stop_ind = json_raw_string.index("')")

json_data = json_raw_string[start_ind:stop_ind]
json_data = json_data.encode("utf8").decode("unicode_escape")

rl_season_wise_meta_df = pd.json_normalize(json.loads(json_data)["season"])
rl_season_wise_meta_df.insert(0, "Player", "Robert Lewandowski")

# %%
rl_season_wise_meta_df
# Out:
#                Player position  ...             xGChain           xGBuildup
# 0  Robert Lewandowski       FW  ...   18.06838420033455  3.7300929129123688
# 1  Robert Lewandowski       FW  ...   31.74017623066902   5.689343474805355
# 2  Robert Lewandowski       FW  ...   39.65040745027363   9.743498254567385
# 3  Robert Lewandowski       FW  ...    41.9232893884182   8.940890244208276
# 4  Robert Lewandowski       FW  ...  28.035747051239014   5.410496477037668
# 5  Robert Lewandowski       FW  ...   33.58735306560993   7.891287753358483
# 6  Robert Lewandowski       FW  ...   34.54226553440094   8.226694845594466
# 7  Robert Lewandowski       FW  ...   23.31542954593897   4.924822298809886
#
# [8 rows x 18 columns]

# %%
rl_season_wise_meta_df = rl_season_wise_meta_df[rl_season_wise_meta_df["season"] == "2021"]

# %%
rl_season_wise_meta_df
# Out:
#                Player position  ...            xGChain           xGBuildup
# 0  Robert Lewandowski       FW  ...  18.06838420033455  3.7300929129123688
#
# [1 rows x 18 columns]

# %%
# Scrape Insigne shot data:
json_raw_string = page_html.findAll(name="script")[3].text
start_ind = json_raw_string.index("\\")
stop_ind = json_raw_string.index("')")

json_data = json_raw_string[start_ind:stop_ind]
json_data = json_data.encode("utf8").decode("unicode_escape")

rl_shots_df = pd.json_normalize(json.loads(json_data))
rl_shots_df.insert(0, "Player", "Robert Lewandowski")

# %%
rl_shots_df
# Out:
#                   Player      id  ...   player_assisted   lastAction
# 0     Robert Lewandowski   24344  ...  Gianluca Gaudino      Chipped
# 1     Robert Lewandowski   24351  ...       David Alaba  Throughball
# 2     Robert Lewandowski   24561  ...      Philipp Lahm         Pass
# 3     Robert Lewandowski   24562  ...    Sebastian Rode         Pass
# 4     Robert Lewandowski   24574  ...       David Alaba      Chipped
# ...                  ...     ...  ...               ...          ...
# 1001  Robert Lewandowski  446373  ...              None     Standard
# 1002  Robert Lewandowski  446377  ...              None     Standard
# 1003  Robert Lewandowski  447571  ...     Jamal Musiala         Pass
# 1004  Robert Lewandowski  447575  ...    Kingsley Coman       Aerial
# 1005  Robert Lewandowski  447583  ...  Corentin Tolisso       Aerial
#
# [1006 rows x 21 columns]

# %%
rl_shots_df = rl_shots_df[rl_shots_df["season"]=="2021"]

# %%
rl_shots_df
# Out:
#                   Player      id  ...   player_assisted   lastAction
# 943   Robert Lewandowski  425533  ...    Josip Stanisic       Aerial
# 944   Robert Lewandowski  425534  ...     Leon Goretzka     HeadPass
# 945   Robert Lewandowski  425536  ...   Alphonso Davies  Throughball
# 946   Robert Lewandowski  425543  ...    Joshua Kimmich        Cross
# 947   Robert Lewandowski  425545  ...        Leroy Sané        Cross
# ...                  ...     ...  ...               ...          ...
# 1001  Robert Lewandowski  446373  ...              None     Standard
# 1002  Robert Lewandowski  446377  ...              None     Standard
# 1003  Robert Lewandowski  447571  ...     Jamal Musiala         Pass
# 1004  Robert Lewandowski  447575  ...    Kingsley Coman       Aerial
# 1005  Robert Lewandowski  447583  ...  Corentin Tolisso       Aerial
#
# [63 rows x 21 columns]

# %%
# Scrape Messi player stats:
messi_scrape_url = "https://understat.com/player/2097"
page_connect = urlopen(messi_scrape_url)
page_html = BeautifulSoup(page_connect, "html.parser")

json_raw_string = page_html.findAll(name="script")[1].text
start_ind = json_raw_string.index("\\")
stop_ind = json_raw_string.index("')")

json_data = json_raw_string[start_ind:stop_ind]
json_data = json_data.encode("utf8").decode("unicode_escape")

messi_season_wise_meta_df = pd.json_normalize(json.loads(json_data)["season"])
messi_season_wise_meta_df.insert(0, "Player", "Messi")

# %%
messi_season_wise_meta_df
# Out:
#   Player position  ...             xGChain           xGBuildup
# 0  Messi      Sub  ...   8.129020392894745  3.1627869941294193
# 1  Messi       FW  ...  37.906863175332546   20.33736250922084
# 2  Messi      Sub  ...   34.92346678301692   13.53765751607716
# 3  Messi       FW  ...   38.45987746119499   10.69879900291562
# 4  Messi       FW  ...   48.18063422292471  21.634404016658664
# 5  Messi      FWR  ...   42.52504535019398   18.13351222872734
# 6  Messi      FWR  ...   41.99686624109745  15.196364373899996
# 7  Messi       FW  ...   54.75360991060734   19.75672373920679
#
# [8 rows x 18 columns]

# %%
messi_season_wise_meta_df = messi_season_wise_meta_df[messi_season_wise_meta_df["season"]=="2021"]

# %%
messi_season_wise_meta_df
# Out:
#   Player position  ...            xGChain           xGBuildup
# 0  Messi      Sub  ...  8.129020392894745  3.1627869941294193
#
# [1 rows x 18 columns]

# %%
# Scrape Messi shot data:
json_raw_string = page_html.findAll(name="script")[3].text
start_ind = json_raw_string.index("\\")
stop_ind = json_raw_string.index("')")

json_data = json_raw_string[start_ind:stop_ind]
json_data = json_data.encode("utf8").decode("unicode_escape")

messi_shots_df = pd.json_normalize(json.loads(json_data))
messi_shots_df.insert(0, "Player", "Messi")

# %%
messi_shots_df
# Out:
#      Player      id minute  ...                 date  player_assisted    lastAction
# 0     Messi   32522     22  ...  2014-08-24 20:00:00          Rafinha          Pass
# 1     Messi   32525     41  ...  2014-08-24 20:00:00  Sergio Busquets  BallRecovery
# 2     Messi   32529     62  ...  2014-08-24 20:00:00             None        TakeOn
# 3     Messi   32769      3  ...  2014-08-31 18:00:00            Pedro          Pass
# 4     Messi   32773     27  ...  2014-08-31 18:00:00             None      Standard
# ...     ...     ...    ...  ...                  ...              ...           ...
# 1274  Messi  446499     17  ...  2021-12-04 20:00:00   Marco Verratti  BallRecovery
# 1275  Messi  446511     44  ...  2021-12-04 20:00:00   Marco Verratti        TakeOn
# 1276  Messi  446523     86  ...  2021-12-04 20:00:00             None          None
# 1277  Messi  446526     92  ...  2021-12-04 20:00:00   Ángel Di María          Pass
# 1278  Messi  446527     94  ...  2021-12-04 20:00:00             None      Standard
#
# [1279 rows x 21 columns]

# %%
messi_shots_df = messi_shots_df[messi_shots_df["season"]=='2021']

# %%
messi_shots_df
# Out:
#      Player      id  ...       player_assisted    lastAction
# 1244  Messi  432204  ...  Kylian Mbappe-Lottin          Pass
# 1245  Messi  432208  ...                Neymar          Pass
# 1246  Messi  432209  ...                  None      Standard
# 1247  Messi  432217  ...                Neymar          Pass
# 1248  Messi  435258  ...         Achraf Hakimi          Pass
# 1249  Messi  435267  ...                  None      Standard
# 1250  Messi  435268  ...  Kylian Mbappe-Lottin          Pass
# 1251  Messi  435276  ...                  None      Standard
# 1252  Messi  435280  ...        Ángel Di María          Pass
# 1253  Messi  438676  ...                  None          None
# 1254  Messi  438680  ...                Neymar          Pass
# 1255  Messi  438681  ...                Neymar          Pass
# 1256  Messi  438683  ...  Kylian Mbappe-Lottin          Pass
# 1257  Messi  439323  ...        Ángel Di María       Chipped
# 1258  Messi  439327  ...                  None      Standard
# 1259  Messi  442691  ...                Neymar          Pass
# 1260  Messi  442696  ...        Marco Verratti          Pass
# 1261  Messi  442704  ...                  None       Rebound
# 1262  Messi  442711  ...                  None      Standard
# 1263  Messi  442712  ...  Kylian Mbappe-Lottin          Pass
# 1264  Messi  442713  ...                  None          None
# 1265  Messi  444436  ...         Idrissa Gueye          Pass
# 1266  Messi  444440  ...                  None          None
# 1267  Messi  444443  ...                  None       Rebound
# 1268  Messi  445586  ...        Ángel Di María          Pass
# 1269  Messi  445589  ...                  None      Standard
# 1270  Messi  445594  ...        Ángel Di María          Pass
# 1271  Messi  445595  ...         Achraf Hakimi  BallRecovery
# 1272  Messi  445606  ...                  None       Rebound
# 1273  Messi  445608  ...                  None          None
# 1274  Messi  446499  ...        Marco Verratti  BallRecovery
# 1275  Messi  446511  ...        Marco Verratti        TakeOn
# 1276  Messi  446523  ...                  None          None
# 1277  Messi  446526  ...        Ángel Di María          Pass
# 1278  Messi  446527  ...                  None      Standard
#
# [35 rows x 21 columns]

# %%
season_wise_meta_df = rl_season_wise_meta_df.append(messi_season_wise_meta_df)
season_wise_meta_df
# Out:
#                Player position  ...            xGChain           xGBuildup
# 0  Robert Lewandowski       FW  ...  18.06838420033455  3.7300929129123688
# 0               Messi      Sub  ...  8.129020392894745  3.1627869941294193
#
# [2 rows x 18 columns]

# %%
shots_df = rl_shots_df.append(messi_shots_df)
shots_df
# Out:
#                   Player      id  ...  player_assisted    lastAction
# 943   Robert Lewandowski  425533  ...   Josip Stanisic        Aerial
# 944   Robert Lewandowski  425534  ...    Leon Goretzka      HeadPass
# 945   Robert Lewandowski  425536  ...  Alphonso Davies   Throughball
# 946   Robert Lewandowski  425543  ...   Joshua Kimmich         Cross
# 947   Robert Lewandowski  425545  ...       Leroy Sané         Cross
# ...                  ...     ...  ...              ...           ...
# 1274               Messi  446499  ...   Marco Verratti  BallRecovery
# 1275               Messi  446511  ...   Marco Verratti        TakeOn
# 1276               Messi  446523  ...             None          None
# 1277               Messi  446526  ...   Ángel Di María          Pass
# 1278               Messi  446527  ...             None      Standard
#
# [98 rows x 21 columns]

# %%
shots_df = shots_df.apply(pd.to_numeric, errors="ignore")

# %%
season_wise_meta_df = season_wise_meta_df.apply(pd.to_numeric, errors="ignore")

# %%
num_cols = season_wise_meta_df.select_dtypes(exclude=[object]).columns

# %%
# Setting boundaries and midpoint:
x_lims = [0, 1.15]
y_lims = [0, 0.74]

x_mid = x_lims[1]/2
y_mid = y_lims[1]/2

# Setting color and linewidth:
background_color = "black"
line_color = "white"
line_width = 2.

# %%
#@title
def create_full_pitch(x_lims, y_lims, background_color="white", line_color="black", line_width=2.):
    """
    Function to create a full-scale pitch based on input dimensions
    :params:
    x_lims: min and max limits for the length of the field
    y_lims: min and max limits for the width/breadth of the field
    background_color: Background color of the field
    line_color: Color for all the lines in the field (Keep this color in contrast with background_color for optimal visual results)
    line_width: The thickness of the outer and center lines
    """
    # Create figure:
    fig = plt.figure(facecolor=background_color, figsize=(12, 7))
    ax = fig.add_subplot(111, facecolor=background_color)

    # Pitch Outline & Centre Line
    plt.plot([x_lims[0], x_lims[0]], [y_lims[0], y_lims[1]], linewidth=line_width, color=line_color)  # left goal-line
    plt.plot([x_lims[0], x_lims[1]], [y_lims[1], y_lims[1]], linewidth=line_width, color=line_color)  # Upper side-line
    plt.plot([x_lims[1], x_lims[1]], [y_lims[1], y_lims[0]], linewidth=line_width, color=line_color)  # Right goal-line
    plt.plot([x_lims[1], x_lims[0]], [y_lims[0], y_lims[0]], linewidth=line_width, color=line_color)  # Lower side-line
    plt.plot([x_mid, x_mid], [y_lims[0], y_lims[1]], linewidth=line_width, color=line_color)  # Center line

    # Left Penalty Area
    plt.plot([x_lims[0]+.18, x_lims[0]+.18], [y_mid - .22, y_mid + .22], color=line_color)
    plt.plot([x_lims[0], x_lims[0]+.18], [y_mid + .22, y_mid + .22], color=line_color)
    plt.plot([x_lims[0], x_lims[0]+.18], [y_mid - .22, y_mid - .22], color=line_color)

    # Right Penalty Area
    plt.plot([x_lims[1] - .18, x_lims[1] - .18], [y_mid - .22, y_mid + .22], color=line_color)
    plt.plot([x_lims[1], x_lims[1] - .18], [y_mid + .22, y_mid + .22], color=line_color)
    plt.plot([x_lims[1], x_lims[1] - .18], [y_mid - .22, y_mid - .22], color=line_color)

    # Left 6yd box Area
    plt.plot([x_lims[0]+.06, x_lims[0]+.06], [y_mid - .06, y_mid + .06], color=line_color)
    plt.plot([x_lims[0], x_lims[0]+.06], [y_mid + .06, y_mid + .06], color=line_color)
    plt.plot([x_lims[0], x_lims[0]+.06], [y_mid - .06, y_mid - .06], color=line_color)

    # # Right 6yd box Area
    plt.plot([x_lims[1] - .06, x_lims[1] - .06], [y_mid - .06, y_mid + .06], color=line_color)
    plt.plot([x_lims[1], x_lims[1] - .06], [y_mid + .06, y_mid + .06], color=line_color)
    plt.plot([x_lims[1], x_lims[1] - .06], [y_mid - .06, y_mid - .06], color=line_color)

    # Prepare Circles
    centre_circle = plt.Circle((x_mid, y_mid), .1, color=line_color, fill=False)
    centre_spot = plt.Circle((x_mid, y_mid), 0.005, color=line_color)
    left_pen_spot = plt.Circle((x_lims[0]+0.12, y_mid), 0.005, color=line_color)
    right_pen_spot = plt.Circle((x_lims[1] - 0.12, y_mid), 0.005, color=line_color)

    # Draw Circles
    ax.add_patch(centre_circle)
    ax.add_patch(centre_spot)
    ax.add_patch(left_pen_spot)
    ax.add_patch(right_pen_spot)

    # Prepare Arcs
    left_arc = Arc((x_lims[0] + .12, y_mid), height=.183, width=.183, angle=0, theta1=310, theta2=50, color=line_color)
    right_arc = Arc((x_lims[1] - .12, y_mid), height=.183, width=.183, angle=0, theta1=130, theta2=230, color=line_color)

    # Draw Arcs
    ax.add_patch(left_arc)
    ax.add_patch(right_arc)

    plt.axis("off")

    return ax

# %%
shots_df["X"] = shots_df["X"].multiply(x_lims[1])
shots_df["Y"] = shots_df["Y"].multiply(y_lims[1])

# %%
ax1 = create_full_pitch(x_lims, y_lims)

sns.scatterplot(x="X", y="Y", data=shots_df[shots_df["Player"] == "Robert Lewandowski"], size="xG", ax=ax1)

ax1.set_xlim([x_mid, x_lims[1]])
ax1.set_ylim(y_lims)
# Out:
# (0.0, 0.74)

# %%
ax2 = create_full_pitch(x_lims, y_lims)

sns.scatterplot(x="X", y="Y", data=shots_df[shots_df["Player"] == "Messi"], size="xG", ax=ax2)

ax2.set_xlim([x_mid, x_lims[1]])
ax2.set_ylim(y_lims)
# Out:
# (0.0, 0.74)

# %%
ax1 = create_full_pitch(x_lims, y_lims)
print("Insigne Heat Map")
sns.kdeplot(x="X", y="Y", data=shots_df[shots_df["Player"] == "Robert Lewandowski"], shade=True, n_levels=10, ax=ax1, color="black")

ax1.set_xlim([x_mid, x_lims[1]])
ax1.set_ylim(y_lims)
# Out:
# Insigne Heat Map
# (0.0, 0.74)

# %%
ax1 = create_full_pitch(x_lims, y_lims)

sns.kdeplot(x="X", y="Y", data=shots_df[shots_df["Player"] == "Messi"], shade=True, n_levels=10, ax=ax1, color="#152238")

ax1.set_xlim([x_mid, x_lims[1]])
ax1.set_ylim(y_lims)
# Out:
# (0.0, 0.74)

# %%
season_wise_meta_df
# Out:
#                Player position  games  ...       npxG    xGChain  xGBuildup
# 0  Robert Lewandowski       FW     15  ...  13.780690  18.068384   3.730093
# 0               Messi      Sub      9  ...   3.859868   8.129020   3.162787
#
# [2 rows x 18 columns]

# %%
radar_df = season_wise_meta_df.groupby(["Player"])[num_cols].sum().reset_index()

# %%
radar_df
# Out:
#                Player  games  goals  ...       npxG    xGChain  xGBuildup
# 0               Messi      9      1  ...   3.859868   8.129020   3.162787
# 1  Robert Lewandowski     15     16  ...  13.780690  18.068384   3.730093
#
# [2 rows x 16 columns]

# %%
radar_df.columns
# Out:
# Index(['Player', 'games', 'goals', 'shots', 'time', 'xG', 'assists', 'xA',
#        'key_passes', 'season', 'yellow', 'red', 'npg', 'npxG', 'xGChain',
#        'xGBuildup'],
#       dtype='object')

# %%
cols_for_radar = ['goals', 'shots', 'xG',
                  'assists', 'xA', 'key_passes',
                  'npg', 'npxG', 'xGChain', 'xGBuildup']

# %%
per90Cols = ['goals', 'shots', 'xG',
             'assists', 'xA', 'key_passes', 'xGChain', 'xGBuildup']

for col in per90Cols:
    radar_df[col + "Per90"] = radar_df[col].divide(radar_df["time"]).multiply(90)

# %%
cols_for_radar = [i + "Per90" for i in per90Cols]

# %%
radar_df[cols_for_radar]
# Out:
#    goalsPer90  shotsPer90  ...  xGChainPer90  xGBuildupPer90
# 0    0.130624    4.571843  ...      1.061846        0.413136
# 1    1.131186    4.454046  ...      1.277419        0.263714
#
# [2 rows x 8 columns]

# %%
radar_df[cols_for_radar].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   goalsPer90       2 non-null      float64
#  1   shotsPer90       2 non-null      float64
#  2   xGPer90          2 non-null      float64
#  3   assistsPer90     2 non-null      float64
#  4   xAPer90          2 non-null      float64
#  5   key_passesPer90  2 non-null      float64
#  6   xGChainPer90     2 non-null      float64
#  7   xGBuildupPer90   2 non-null      float64
# dtypes: float64(8)
# memory usage: 256.0 bytes

# %%
radar_df
# Out:
#                Player  games  ...  xGChainPer90  xGBuildupPer90
# 0               Messi      9  ...      1.061846        0.413136
# 1  Robert Lewandowski     15  ...      1.277419        0.263714
#
# [2 rows x 24 columns]

# %%
# Initiate the plotly go figure
fig = go.Figure()
# Add Radar plots for different players:
fig.add_trace(go.Scatterpolar(
    r=radar_df.loc[(radar_df["Player"] == "Robert Lewandowski"), cols_for_radar].sum(),
    theta=cols_for_radar,
    fill='toself',
    name='Robert Lewandowski'))
fig.add_trace(go.Scatterpolar(
    r=radar_df.loc[(radar_df["Player"] == "Messi"), cols_for_radar].sum(),
    theta=cols_for_radar,
    fill='toself',
    name="Messi"))
# Additional properties for the plot:
fig.update_layout(
    title="Robert Lewandowski vs Messi 2021-22 League Season",
polar=dict(
    radialaxis=dict(
    visible=True,
    )),
showlegend=True
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4e21e9a9-5eda-4e2f-b4fd-63515b143a7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4e21e9a9-5eda-4e2f-b4fd-63515b143a7a")) {
#                     Plotly.newPlot(
#                         '4e21e9a9-5eda-4e2f-b4fd-63515b143a7a',
#                         [{"fill": "toself", "name": "Robert Lewandowski", "r": [1.131186174391202, 4.454045561665358, 1.1350053756001046, 0.07069913589945012, 0.21678265479729106, 1.3432835820895521, 1.2774191500629297, 0.2637143457675673], "theta": ["goalsPer90", "shotsPer90", "xGPer90", "assistsPer90", "xAPer90", "key_passesPer90", "xGChainPer90", "xGBuildupPer90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Messi", "r": [0.13062409288824384, 4.571843251088534, 0.5041917373462755, 0.39187227866473145, 0.42436346719893037, 2.7431059506531206, 1.0618459148919115, 0.4131361821068908], "theta": ["goalsPer90", "shotsPer90", "xGPer90", "assistsPer90", "xAPer90", "key_passesPer90", "xGChainPer90", "xGBuildupPer90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": " ...
